# %%
import numpy as np 
import time 
import pymanopt
from pymanopt import manifolds, optimizers, tools, core
from pymanopt.core.problem  import Problem
from typing import Sequence
from scipy.spatial.transform import Rotation as R

import networkx as nx
from useful_function_joint import *
from scipy import optimize
from scipy.optimize import Bounds

deg2rad = np.pi/180.
rad2deg = 180./np.pi

# %load_ext autoreload
# %autoreload 2

# %%
def load_kuka_KR_10_R1100(scale_shift=10,joints_ref=np.array([0,-90,90,0,0,0])*np.pi/180):

    e1 = np.array((1,0,0))*scale_shift
    e2 = np.array((0,1,0))*scale_shift
    e3 = np.array((0,0,1))*scale_shift
    e0 = np.array([0,0,0])

    t1 = np.array((25,0,0))
    t2 = np.array((560,0,0))
    t3 = np.array((515,0,25))
    t4 = np.array((0,0,0))
    t5 = np.array((90,0,0))

    R1 = Rz(joints_ref[0])
    R2 = Ry(joints_ref[1])
    R3 = Ry(joints_ref[2])
    R4 = Rx(joints_ref[3])
    R5 = Ry(joints_ref[4])
    R6 = Rx(joints_ref[5])

    T1 = T(t1)
    T2 = T(t2)
    T3 = T(t3)
    T4 = T(t4)
    T5 = T(t5)

    axes = ['z','y','y','x','y','x']

    translation = [T(e0),T1,T2,T3,T4,T5]
    rotation = [R1,R2,R3,R4,R5,R6]

    step_vect = {'z': [e0,e3],
                'y': [e2,-e2*0],
                'x': [e0,-e1]}
    
    return axes, translation, rotation, step_vect, e0, e1, e2, e3

# %%
def sol_by_edge(Y_star,new_edge_order,n_anchor,e):

    for i in range(len(new_edge_order)):
        if (e[0] == new_edge_order[i][0]) and (e[1] == new_edge_order[i][1]):
            if i < n_anchor:
                return Y_star[0].transpose()[i,:]
            else:
                return Y_star[1].transpose()[i-n_anchor,:]


def sol_to_config_kuka_KR_10_R1100(G,Y_star,new_edge_order,n_anchor,scale_shift=10):

    e1 = np.array((1,0,0))*scale_shift
    e2 = np.array((0,1,0))*scale_shift
    e3 = np.array((0,0,1))*scale_shift
    e0 = np.array([0,0,0])

    t1 = np.array((25,0,0))
    t2 = np.array((560,0,0))
    t3 = np.array((515,0,25))
    t4 = np.array((0,0,0))
    t5 = np.array((90,0,0))

    R1 = Rz
    R2 = Ry
    R3 = Ry
    R4 = Rx
    R5 = Ry
    R6 = Rx

    T1 = T(t1)
    T2 = T(t2)
    T3 = T(t3)
    T4 = T(t4)
    T5 = T(t5)

    axes = ['z','y','y','x','y','x']

    translation = [T(e0),T1,T2,T3,T4,T5]
    rotation = [R1,R2,R3,R4,R5,R6]

    step_vect = {'z': [e0,e3],
                'y': [e2,-e2*0],
                'x': [e0,-e1]}
    
    dir_ref = nx.get_edge_attributes(G,'dir_ref')
    
    v3 = norm(np.array([ 5.40000000e+02, -9.42477796e-04,  5.85000000e+02])-np.array([ 2.50000000e+01, -4.36332313e-05,  5.60000000e+02]))
    print('v3',  np.array([ 5.40000000e+02, -9.42477796e-04,  5.85000000e+02])-np.array([ 2.50000000e+01, -4.36332313e-05,  5.60000000e+02]), norm(np.array([ 5.40000000e+02, -9.42477796e-04,  5.85000000e+02])-np.array([ 2.50000000e+01, -4.36332313e-05,  5.60000000e+02])))
    reference_edges = [('a2_minus', 'a2_plus'), ('a2_minus', 'a3_minus'),('a3_minus', 'a4_origin'), ('a5_minus', 'a5_plus'),('a6_minus', 'a6_origin')]
    reference_direction = [norm(e2),norm(e1),norm(e1),norm(e2),norm(e1)]
    
    RR = Ry(-np.arctan2(v3[2],v3[0]))[:3,:3]
    directions_sol = [sol_by_edge(Y_star,new_edge_order,n_anchor,e) for e in reference_edges]
    print(directions_sol)
    ww = directions_sol[0]
    joints = [np.arctan2(ww[0],ww[1])]
    print('e1',rotation[0](joints[-1])[:3,:3].transpose()@ww)
    print('a1',joints[0]*180/np.pi,ww)
    y_list =  [1,4]
    for i in range(1,5):
        transform = []
        for j in reversed(range(i)):
            transform.append(rotation[j](-joints[j])[:3,:3])
        if len(transform)>1:
            transform = np.array(transform)
            transformation = np.linalg.multi_dot(transform)
        else:
            transformation = transform[0]
        #joints.append(np.arccos((np.linalg.inv(transformation)@directions_sol[i])@reference_direction[i]))
        ww = ((transformation)@directions_sol[i])
        print('ww:',ww,directions_sol[i])
        if i in y_list:
            print(ww)
            joints.append(-np.arctan2(ww[2],ww[0]))
        elif i == 2:
            ww = RR.transpose()@ww
            print(ww)
            joints.append(-np.arctan2(ww[2],ww[0]))
        else:
            joints.append(np.arctan2(ww[2],ww[1]))

        print(i,rotation[i](joints[-1])[:3,:3].transpose()@ww,reference_direction[i])
        print('----------------------------')
    
    return joints

# %%
joint = sol_to_config_kuka_KR_10_R1100(G,Y_D3,new_edge_order,n_anchor,scale_shift)
joint.append(0)
#joint[1] = -joint[1]
#joint[-2] = np.pi-joint[-2]
print([180/np.pi*j for j in joint])
print(pose_robot_(joint,'camera'))
print(position,direction)
print(np.linalg.norm(pose_robot_(joint,'camera')[:3,3] - position), np.linalg.norm(direction - pose_robot_(joint,'camera')[:3,0]))
# Out:
# v3 [ 5.15000000e+02 -8.98844565e-04  2.50000000e+01] [ 9.98823833e-01 -1.74327645e-06  4.84865939e-02]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 joint = sol_to_config_kuka_KR_10_R1100(G,Y_D3,new_edge_order,n_anchor,scale_shift)
#       2 joint.append(0)
#       3 #joint[1] = -joint[1]
#       4 #joint[-2] = np.pi-joint[-2]
#
# Cell In[5], line 54, in sol_to_config_kuka_KR_10_R1100(G, Y_star, new_edge_order, n_anchor, scale_shift)
#      51 reference_direction = [norm(e2),norm(e1),norm(e1),norm(e2),norm(e1)]
#      53 RR = Ry(-np.arctan2(v3[2],v3[0]))[:3,:3]
# ---> 54 directions_sol = [sol_by_edge(Y_star,new_edge_order,n_anchor,e) for e in reference_edges]
#      55 print(directions_sol)
#      56 ww = directions_sol[0]
#
# Cell In[5], line 54, in <listcomp>(.0)
#      51 reference_direction = [norm(e2),norm(e1),norm(e1),norm(e2),norm(e1)]
#      53 RR = Ry(-np.arctan2(v3[2],v3[0]))[:3,:3]
# ---> 54 directions_sol = [sol_by_edge(Y_star,new_edge_order,n_anchor,e) for e in reference_edges]
#      55 print(directions_sol)
#      56 ww = directions_sol[0]
#
# Cell In[5], line 8, in sol_by_edge(Y_star, new_edge_order, n_anchor, e)
#       6     return Y_star[0].transpose()[i,:]
#       7 else:
# ----> 8     return Y_star[1].transpose()[i-n_anchor,:]
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
hh = [('a2_minus', 'a2_plus'),
 ('a2_minus', 'a3_minus'),
 ('a2_minus', 'a3_plus'),
 ('a2_plus', 'a3_minus'),
 ('a2_plus', 'a3_plus'),
 ('a3_minus', 'a3_plus')]

y = []
for i,e in enumerate(new_edge_order):
    if e in hh:
        y.append(Y_D3.transpose()[i,:])

print(np.array(y).shape)
y = np.array(y)
print(np.linalg.svd(y.transpose()@y)[1])
# Out:
# (6, 3)
# [3.34228150e+00 2.65771698e+00 1.52396237e-06]

# %%
def recover_config(scale_shift,X):

    joints_ref = np.array([0,0,0,0,0,0])
    axes, translation, rotation, step_vect, e0, e1, e2, e3 = load_kuka_KR_10_R1100(scale_shift,joints_ref)
    pose_ref_ax = pose_axes(joints_ref)
    #pose_ref_ax = [p[:3,3] for p in pose_ref_ax]

    rotation = [Rz, Ry, Ry, Rx, Ry, Rx]
    d_rotation = [dRz, dRy1, dRy1, dRx1,dRy1, dRx1]


    def cost(v_,X_goal):
        
        v = [v_l for v_l in v_]
        v.append(0)
        v = np.array(v)
        #v = np.array([90,-90,90,0,0,0])*deg2rad
        pose_ax_v = pose_axes(v)
        
        X = []

        for j in range(6):
            ax = axes[j]
            v1,v2 = step_vect[ax] 
            #print(pose)
            X.append(pose_ax_v[j][:3,3] + pose_ax_v[j][:3,:3]@v2)
            X.append(pose_ax_v[j][:3,3] + pose_ax_v[j][:3,:3]@v1)
        
        #print(np.array(X))
        X = np.array(X) - X_goal[2:,:]
        
        return np.linalg.norm(X)**2
    
    min_absolute_bound = np.array([-180.0, -189.75,15,-183.5,-119.5])*deg2rad
    max_absolute_bound = np.array([180.0, -25,155.5,183.5,119.5])*deg2rad
    
    bounds = Bounds(min_absolute_bound, max_absolute_bound)

    cost_goal = lambda  x: cost(x,X)
    res = optimize.minimize(
            cost_goal,
            # cost,
            x0 = np.array([90,-90,90,0,0])*deg2rad,
            jac='3-point',
            # jac=grad,
            bounds = bounds,
            method='Nelder-Mead',
            options={"xatol": 1e-7, "fatol": 1e-7, 'disp': True,'maxiter': 1000},
        )
    
    print(res.fun)
    return res.x

# %%
recover_config(scale_shift,X)
# Out:
# Optimization terminated successfully.
#          Current function value: 5150189.682170
#          Iterations: 710
#          Function evaluations: 1118
# 5150189.682170348
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_minimize.py:550: RuntimeWarning: Method Nelder-Mead does not use gradient information (jac).
#   warn('Method %s does not use gradient information (jac).' % method,
# array([ 3.14159265, -1.47486428,  0.26179939,  0.97554455, -0.37638745])

# %%
np.linalg.svd(X[4:8,:],full_matrices=False)
# Out:
# SVDResult(U=array([[ 0.00975122,  0.0337248 , -0.9192485 ],
#        [ 0.56935465, -0.57690723, -0.24252198],
#        [ 0.22968742,  0.79501185, -0.19324257],
#        [ 0.78929328,  0.18438233,  0.24253368]]), S=array([1246.53150996,  641.40711891,    3.32403318]), Vh=array([[-0.87148908, -0.48704347,  0.0574059 ],
#        [ 0.49040616, -0.86478344,  0.10794165],
#        [-0.0029286 ,  0.12222218,  0.99249844]]))

# %%
nx.get_node_attributes(G,'pos_ref')
# Out:
# {'x': array([100,   0,   0]),
#  'y': array([  0, 100,   0]),
#  'a1_plus': array([  0.,   0., 100.]),
#  'a1_origin': array([0., 0., 0.]),
#  'a2_minus': array([ 1.5308085e-15, -2.5000000e+01,  0.0000000e+00]),
#  'a2_plus': array([100., -25.,   0.]),
#  'a3_minus': array([ 1.5308085e-15, -2.5000000e+01,  5.6000000e+02]),
#  'a3_plus': array([100., -25., 560.]),
#  'a4_minus': array([ 2.69422296e-14, -4.40000000e+02,  5.85000000e+02]),
#  'a4_origin': array([ 3.30654636e-14, -5.40000000e+02,  5.85000000e+02]),
#  'a5_minus': array([ 3.30654636e-14, -5.40000000e+02,  5.85000000e+02]),
#  'a5_plus': array([ 100., -540.,  585.]),
#  'a6_minus': array([ 3.24531402e-14, -5.30000000e+02,  5.85000000e+02]),
#  'a6_origin': array([ 3.85763742e-14, -6.30000000e+02,  5.85000000e+02])}

# %%
def norm(x):
    return x/max(np.linalg.norm(x),10**-9)

def create_graph(scale_shift,joints_ref,position = None, direction= None, anchor = False):

    axes, translation, rotation, step_vect, e0, e1, e2, e3 = load_kuka_KR_10_R1100(scale_shift,joints_ref)
    
    G = nx.Graph()

    G.add_node(1,pos_ref=e1)
    G.add_node(2,pos_ref=e2)
    G.add_edge(1,2, weight  = np.linalg.norm(e1-e2), dir_ref  = -norm(e1-e2))


    count = 2

    for i, ax in enumerate(axes):
        v1,v2 = step_vect[ax]

        transform = []

        for j in range(i+1):
            transform.append(translation[j])
            transform.append(rotation[j])
        transform = np.array(transform)
        transformation = np.linalg.multi_dot(transform)

        G.add_node(count+1,pos_ref=(transformation@T(v2))[:3,3])
        G.add_node(count+2,pos_ref=(transformation@T(v1))[:3,3])

        node_pos_ref = nx.get_node_attributes(G,'pos_ref')

        G.add_edge(count+2,count+1, weight = np.linalg.norm(node_pos_ref[count+1]-node_pos_ref[count+2]))
        
        G.add_edge(count,count+1, weight = np.linalg.norm(node_pos_ref[count+1]-node_pos_ref[count]))
        G.add_edge(count-1,count+1, weight = np.linalg.norm(node_pos_ref[count+1]-node_pos_ref[count-1]))

        G.add_edge(count,count+2, weight = np.linalg.norm(node_pos_ref[count+2]-node_pos_ref[count]))
        G.add_edge(count-1,count+2, weight = np.linalg.norm(node_pos_ref[count+2]-node_pos_ref[count-1]))

        count = count + 2

    mapping = {1: "x", 2: "y", 3: "a1_plus", 4: "a1_origin", 5: "a2_minus", 6: "a2_plus", 7: "a3_minus", 8:"a3_plus", 
            9: "a4_minus", 10:"a4_origin", 11: "a5_minus", 12:"a5_plus", 13: "a6_minus", 14:"a6_origin"}

    G = nx.relabel_nodes(G, mapping)

    G.add_edge('a1_origin','a6_origin', weight = np.linalg.norm(position))

    G.add_edge('x','a6_origin', weight = np.linalg.norm(position-e1))
    G.add_edge('y','a6_origin', weight = np.linalg.norm(position-e2))
    G.add_edge('a1_plus','a6_origin', weight = np.linalg.norm(position-e3))
               
    if direction is not None:
        G.add_edge('a1_origin','a6_minus', weight = np.linalg.norm(position-scale_shift*direction))

        G.add_edge('x','a6_minus', weight = np.linalg.norm(position-scale_shift*direction-e1))
        G.add_edge('y','a6_minus', weight = np.linalg.norm(position-scale_shift*direction-e2))
        G.add_edge('a1_plus','a6_minus', weight = np.linalg.norm(position-scale_shift*direction-e3))
    else:
        direction = None

    if anchor:
        if direction is not None:
            fix_edges = [('x', 'y'), ('x', 'a1_plus'), ('x', 'a1_origin'), ('x', 'a6_origin'), ('x', 'a6_minus'),
                        ('y', 'a1_plus'), ('y', 'a1_origin'), ('y', 'a6_origin'), ('y', 'a6_minus'),
                        ('a1_plus', 'a1_origin'),('a1_plus', 'a6_origin'), ('a1_plus', 'a6_minus'),
                        ('a6_minus', 'a6_origin'),('a1_origin', 'a6_origin'),('a1_origin', 'a6_minus')]
        else:
            fix_edges = [('x', 'y'), ('x', 'a1_plus'), ('x', 'a1_origin'), ('x', 'a6_origin'), 
                        ('y', 'a1_plus'), ('y', 'a1_origin'), ('y', 'a6_origin'), 
                        ('a1_plus', 'a1_origin'),('a1_plus', 'a6_origin'),
                        ('a1_origin', 'a6_origin')]

        other_edges = []
        for e in G.edges():
            if e not in fix_edges:
                other_edges.append(e)

        if direction is not None:
            direction_ref = {('x', 'y'): norm(e2-e1) , ('x', 'a1_plus'): norm(e3-e1), ('x', 'a1_origin'): norm(-e1), 
                            ('x', 'a6_origin'): norm(position-e1), ('x', 'a6_minus'): norm(position - np.linalg.norm(e1)*direction -e1),
                        ('y', 'a1_plus'): norm(e3-e2), ('y', 'a1_origin'): norm(-e2), ('y', 'a6_origin'): norm(position-e2),
                        ('y', 'a6_minus'): norm(position - np.linalg.norm(e1)*direction - e2),
                        ('a1_plus', 'a1_origin'): norm(-e3),('a1_plus', 'a6_origin'): norm(position-e3),
                        ('a1_plus', 'a6_minus'): norm(position - np.linalg.norm(e1)*direction-e3),
                        ('a6_minus', 'a6_origin'): norm(direction),('a1_origin', 'a6_origin'):norm(position),
                        ('a1_origin', 'a6_minus'): norm(position - np.linalg.norm(e1)*direction)}
        else:
            direction_ref = {('x', 'y'): norm(e2-e1) , ('x', 'a1_plus'): norm(e3-e1), ('x', 'a1_origin'): norm(-e1), 
                            ('x', 'a6_origin'): norm(position-e1), 
                        ('y', 'a1_plus'): norm(e3-e2), ('y', 'a1_origin'): norm(-e2), ('y', 'a6_origin'): norm(position-e2),
                        ('a1_plus', 'a1_origin'): norm(-e3),('a1_plus', 'a6_origin'): norm(position-e3),('a1_origin', 'a6_origin'):norm(position)}
        
        pos_ref = nx.get_node_attributes(G,'pos_ref')

        new_edge_order = fix_edges.copy()
        new_edge_order.extend(other_edges.copy())

        A_ = []
        for e in fix_edges:
            A_.append(direction_ref[e])
        A_ = np.array(A_).transpose()
    else:
        fix_edges = []
        other_edges = [e for e in G.edges()]
        new_edge_order = other_edges.copy()
        A_ = None
        
        n_anchor = 0
        n = len(new_edge_order)

    weight = nx.get_edge_attributes(G, "weight")
    D = np.diag([weight[i] for i in new_edge_order])

    C = incidence_matrix_(G,oriented=True, edgelist=new_edge_order).toarray()
    C = np.array(C)

    n = len(other_edges)
    n_anchor = len(fix_edges)
    
    Y_init = np.zeros((3,n))

    for i, e in enumerate(other_edges):
        i = i 
        p1 = G.nodes[e[0]]['pos_ref']
        p2 = G.nodes[e[1]]['pos_ref']
        Y_init[:,i] = (p2-p1)/max(np.linalg.norm(p2-p1),10**-9)
        
        return G, fix_edges, other_edges, new_edge_order, n,n_anchor, A_, D,C,Y_init, e0, e1, e2, e3

# %%
def simple_IK(d,C,D,A_,n, n_anchor,max_iter,ind,W=None,Y_init=None,use_rand=False):
    if  W is None:
        W = np.eye(D.shape[0])
    if n_anchor > 0:    
        if d > 3:
            A = np.zeros((d,n_anchor))
            A[:3,:] = A_[:3,:]
        else:
            if A_.shape[0] == d:
                A = A_
            elif A_.shape[0] > d:
                A = A_[:d,:]
            else:
                A = np.zeros((d,n_anchor))
                A[:3,:] = A_[:3,:]

        manifold_ = manifolds.Product([manifolds.ConstantFactory(A) , manifolds.Oblique(d,n)])
    else:
        manifold_ = manifolds.Oblique(d,n)

    Q2 = -D@(W@C.transpose()@np.linalg.pinv(C@W@C.transpose()))@C@W@D
    Q1 = D@W@D

    if n_anchor > 0:
        zero = np.zeros_like(A)
        @pymanopt.function.numpy(manifold_)
        def cost(A,Y_):
            print(A.shape,Y_.shape)
            Y = np.concatenate([A,Y_],axis=1)
            return np.trace(Q1 + Q2@Y.transpose()@Y) 

        @pymanopt.function.numpy(manifold_)
        def euclidean_gradient(A,Y_):
            Y = np.concatenate([A,Y_],axis=1)
            grad = 2*Q2[n_anchor:,:]@Y.transpose()
            return [zero,grad.transpose() ]
                                
        @pymanopt.function.numpy(manifold_)
        def euclidean_hessian(A,Y_,U_A, U):
            U_ = np.concatenate([U_A,U],axis=1)
            hess = 2*Q2[n_anchor:,:]@U_.transpose()
            return [zero,hess.transpose()]
    else:
        @pymanopt.function.numpy(manifold_)
        def cost(Y):
            return np.trace(Q1 + Q2@Y.transpose()@Y) 

        @pymanopt.function.numpy(manifold_)
        def euclidean_gradient(Y):
            grad = 2*Q2@Y.transpose()
            return grad.transpose() 
                                
        @pymanopt.function.numpy(manifold_)
        def euclidean_hessian(Y,U):
            hess = 2*Q2@U.transpose()
            return hess.transpose()


    problem = Problem(manifold=manifold_, 
                      cost=cost,
                      euclidean_gradient=euclidean_gradient, 
                      euclidean_hessian=euclidean_hessian)

    optimizer = optimizers.TrustRegions(max_iterations=max_iter,use_rand=use_rand)
    
    if  Y_init is None:
        Y_init_ = manifold_.random_point()
    elif len(Y_init) == 2:
        if Y_init[0].shape[0] == d:
            print(1)
            Y_init_ = Y_init
        elif Y_init[0].shape[0] < d:
            print(2)
            Y_init_ = np.zeros((d,n))
            Y_init_[:Y_init[0].shape[0],:] = Y_init[1]
            Y_init_ = [A, Y_init_]
        else:
            print(3)
            U,S,V = np.linalg.svd(Y_init[1],full_matrices=False)
            Y_init_ = [A, U[:d,:d]@np.diag(S)[:d,:]@V/np.maximum(np.linalg.norm(U[:d,:d]@np.diag(S)[:d,:]@V,axis=0),10**-9)]
    else:
        if Y_init.shape[0] == d:
            print(1)
            Y_init_ = Y_init
        elif Y_init.shape[0] < d:
            print(2)
            Y_init_ = np.zeros((d,n))
            Y_init_[:Y_init.shape[0],:] = Y_init
        else:
            print(3)
            U,S,V = np.linalg.svd(Y_init,full_matrices=False)
            Y_init_ = U[:d,:d]@np.diag(S)[:d,:]@V/np.maximum(np.linalg.norm(U[:d,:d]@np.diag(S)[:d,:]@V,axis=0),10**-9)
    
    Y_star = optimizer.run(problem,initial_point=Y_init_).point

    return Y_star

# %%
joints_ref=np.array([90.000,-90,90,0,0,0])*np.pi/180
scale_shift = 8*10**2

position = pose_robot_(joints_ref,'camera')[:3,3] # np.array([200,200,695])#
print(position)
direction = pose_robot_(joints_ref,'camera')[:3,0] #np.array([1,0,0])
direction = direction/np.linalg.norm(direction)

G, fix_edges, other_edges, new_edge_order, n,n_anchor, A_, D,C,Y_init, e0, e1, e2, e3 = create_graph(scale_shift,joints_ref,position, direction= direction,anchor =False)
# Out:
# [ 3.85763742e-14 -6.30000000e+02  5.85000000e+02]

# %%
W = np.diag(np.concatenate([np.ones(n_anchor),np.ones(n)]))
#Y_D10 = simple_IK(3,C,D,A_,n, n_anchor,max_iter=1000,W=W,Y_init=None)
#Y_D5 = simple_IK(5,C,D,A_,n, n_anchor=0,max_iter=1000,ind=[14,19],W=W,Y_init=None) #[A_,Y_init])
Y_D4 = simple_IK(4,C,D,A_,n, n_anchor,max_iter=2000,ind=[14,19],W=W,Y_init=None)
Y_D3 = simple_IK(3,C,D,A_,n, n_anchor,max_iter=3000,ind=[14,19],W=W,Y_init=Y_D4,use_rand = False)
# Out:
# Optimizing...
#                                             f: +2.015643e+07   |grad|: 3.739207e+06
# acc TR+   k:     1     num_inner:     0     f: +1.155004e+07   |grad|: 3.701044e+06   negative curvature
# acc       k:     2     num_inner:     0     f: +3.853218e+06   |grad|: 2.551907e+06   exceeded trust region
# acc       k:     3     num_inner:     2     f: +1.715619e+06   |grad|: 1.717847e+06   exceeded trust region
# acc       k:     4     num_inner:     3     f: +9.023834e+05   |grad|: 1.298547e+06   exceeded trust region
# REJ TR-   k:     5     num_inner:     6     f: +9.023834e+05   |grad|: 1.298547e+06   negative curvature
# acc TR+   k:     6     num_inner:     1     f: +1.758852e+05   |grad|: 3.785225e+05   exceeded trust region
# acc       k:     7     num_inner:     6     f: +1.253797e+05   |grad|: 3.879029e+05   exceeded trust region
# acc       k:     8     num_inner:    14     f: +4.689926e+04   |grad|: 2.709194e+05   exceeded trust region
# acc       k:     9     num_inner:     9     f: +2.733161e+03   |grad|: 4.050357e+04   reached target residual-kappa (linear)
# acc       k:    10     num_inner:    22     f: +2.996181e+02   |grad|: 7.435776e+03   reached target residual-kappa (linear)
# acc       k:    11     num_inner:    29     f: +5.986015e+01   |grad|: 2.677544e+03   reached target residual-kappa (linear)
# acc       k:    12     num_inner:    62     f: +1.087828e+01   |grad|: 1.138714e+03   reached target residual-kappa (linear)
# acc       k:    13     num_inner:    46     f: +3.108691e+00   |grad|: 5.995166e+02   reached target residual-kappa (linear)
# acc       k:    14     num_inner:    44     f: +7.118130e-01   |grad|: 2.112480e+02   reached target residual-kappa (linear)
# acc       k:    15     num_inner:    53     f: +2.131736e-01   |grad|: 1.232395e+02   reached target residual-kappa (linear)
# acc       k:    16     num_inner:    73     f: +5.638344e-02   |grad|: 6.586231e+01   reached target residual-kappa (linear)
# acc       k:    17     num_inner:     8     f: +5.246592e-02   |grad|: 5.875474e+00   reached target residual-kappa (linear)
# acc       k:    18     num_inner:    87     f: +1.409562e-02   |grad|: 4.899678e+01   reached target residual-kappa (linear)
# acc       k:    19     num_inner:     8     f: +1.221639e-02   |grad|: 3.754136e+00   reached target residual-kappa (linear)
# acc       k:    20     num_inner:    87     f: +3.182309e-03   |grad|: 2.988868e+01   reached target residual-kappa (linear)
# acc       k:    21     num_inner:     7     f: +2.594398e-03   |grad|: 2.747175e+00   reached target residual-kappa (linear)
# acc       k:    22     num_inner:    89     f: +6.944531e-04   |grad|: 1.601142e+01   reached target residual-kappa (linear)
# acc       k:    23     num_inner:     7     f: +5.373189e-04   |grad|: 1.197437e+00   reached target residual-kappa (linear)
# acc       k:    24     num_inner:    89     f: +1.417225e-04   |grad|: 6.312897e+00   reached target residual-kappa (linear)
# acc       k:    25     num_inner:     7     f: +1.161744e-04   |grad|: 5.460664e-01   reached target residual-kappa (linear)
# acc       k:    26     num_inner:    38     f: +1.142976e-04   |grad|: 5.418363e-02   reached target residual-kappa (linear)
# acc       k:    27     num_inner:   116     f: +2.967514e-05   |grad|: 3.311873e+00   maximum inner iterations
# acc       k:    28     num_inner:     7     f: +2.271810e-05   |grad|: 2.647215e-01   reached target residual-kappa (linear)
# acc       k:    29     num_inner:    51     f: +2.246314e-05   |grad|: 2.241757e-02   reached target residual-kappa (linear)
# acc       k:    30     num_inner:   116     f: +5.875328e-06   |grad|: 1.456212e+00   maximum inner iterations
# acc       k:    31     num_inner:     7     f: +4.508105e-06   |grad|: 1.303451e-01   reached target residual-kappa (linear)
# acc       k:    32     num_inner:    16     f: +4.479159e-06   |grad|: 1.202050e-02   reached target residual-kappa (linear)
# acc       k:    33     num_inner:   116     f: +1.282989e-06   |grad|: 6.095498e-01   maximum inner iterations
# acc       k:    34     num_inner:     8     f: +1.013695e-06   |grad|: 4.321545e-02   reached target residual-kappa (linear)
# acc       k:    35     num_inner:    53     f: +1.005279e-06   |grad|: 1.507790e-03   reached target residual-theta (superlinear)
# acc       k:    36     num_inner:   116     f: +3.366710e-07   |grad|: 2.475504e-01   maximum inner iterations
# acc       k:    37     num_inner:     7     f: +2.953574e-07   |grad|: 2.399238e-02   reached target residual-kappa (linear)
# acc       k:    38     num_inner:   106     f: +1.010937e-07   |grad|: 1.279538e-01   reached target residual-theta (superlinear)
# acc       k:    39     num_inner:     6     f: +8.571249e-08   |grad|: 1.144247e-02   reached target residual-kappa (linear)
# acc       k:    40     num_inner:   108     f: +3.478851e-08   |grad|: 3.886647e-02   reached target residual-theta (superlinear)
# acc       k:    41     num_inner:    11     f: +3.334833e-08   |grad|: 1.196748e-03   reached target residual-theta (superlinear)
# acc       k:    42     num_inner:   116     f: +7.020844e-09   |grad|: 4.721558e-02   maximum inner iterations
# acc       k:    43     num_inner:     9     f: +4.389108e-09   |grad|: 1.922110e-03   reached target residual-theta (superlinear)
# acc       k:    44     num_inner:   116     f: -2.323873e-09   |grad|: 1.372158e-02   maximum inner iterations
# REJ TR-   k:    45     num_inner:    54     f: -2.323873e-09   |grad|: 1.372158e-02   reached target residual-theta (superlinear)
# REJ TR-   k:    46     num_inner:    54     f: -2.323873e-09   |grad|: 1.372158e-02   reached target residual-theta (superlinear)
# REJ TR-   k:    47     num_inner:    54     f: -2.323873e-09   |grad|: 1.372158e-02   reached target residual-theta (superlinear)
# REJ TR-   k:    48     num_inner:    54     f: -2.323873e-09   |grad|: 1.372158e-02   reached target residual-theta (superlinear)
#  +++ Detected many consecutive TR- (radius decreases).
#  +++ Consider decreasing options.Delta_bar by an order of magnitude.
#  +++ Current values: Delta_bar = 19.6192 and Delta0 = 2.4524
# REJ TR-   k:    49     num_inner:    54     f: -2.323873e-09   |grad|: 1.372158e-02   reached target residual-theta (superlinear)
# REJ TR-   k:    50     num_inner:    54     f: -2.323873e-09   |grad|: 1.372158e-02   reached target residual-theta (superlinear)
# REJ TR-   k:    51     num_inner:    54     f: -2.323873e-09   |grad|: 1.372158e-02   reached target residual-theta (superlinear)
# REJ TR-   k:    52     num_inner:    54     f: -2.323873e-09   |grad|: 1.372158e-02   reached target residual-theta (superlinear)
# REJ TR-   k:    53     num_inner:    54     f: -2.323873e-09   |grad|: 1.372158e-02   reached target residual-theta (superlinear)
# REJ TR-   k:    54     num_inner:    54     f: -2.323873e-09   |grad|: 1.372158e-02   reached target residual-theta (superlinear)
# REJ TR-   k:    55     num_inner:    54     f: -2.323873e-09   |grad|: 1.372158e-02   reached target residual-theta (superlinear)
# REJ TR-   k:    56     num_inner:    54     f: -2.323873e-09   |grad|: 1.372158e-02   reached target residual-theta (superlinear)
# acc TR+   k:    57     num_inner:    35     f: -2.679826e-09   |grad|: 9.712545e-04   exceeded trust region
# REJ TR-   k:    58     num_inner:    85     f: -2.679826e-09   |grad|: 9.712545e-04   exceeded trust region
# REJ TR-   k:    59     num_inner:    47     f: -2.679826e-09   |grad|: 9.712545e-04   exceeded trust region
# REJ TR-   k:    60     num_inner:    25     f: -2.679826e-09   |grad|: 9.712545e-04   exceeded trust region
# REJ TR-   k:    61     num_inner:     4     f: -2.679826e-09   |grad|: 9.712545e-04   exceeded trust region
#  +++ Detected many consecutive TR- (radius decreases).
#  +++ Consider decreasing options.Delta_bar by an order of magnitude.
#  +++ Current values: Delta_bar = 19.6192 and Delta0 = 2.4524
# REJ TR-   k:    62     num_inner:     1     f: -2.679826e-09   |grad|: 9.712545e-04   exceeded trust region
# REJ TR-   k:    63     num_inner:     0     f: -2.679826e-09   |grad|: 9.712545e-04   exceeded trust region
# REJ TR-   k:    64     num_inner:     0     f: -2.679826e-09   |grad|: 9.712545e-04   exceeded trust region
# REJ TR-   k:    65     num_inner:     0     f: -2.679826e-09   |grad|: 9.712545e-04   exceeded trust region
# acc TR+   k:    66     num_inner:     0     f: -3.584660e-09   |grad|: 9.611558e-04   exceeded trust region
# acc TR+   k:    67     num_inner:     0     f: -3.955734e-09   |grad|: 9.412517e-04   exceeded trust region
# REJ TR-   k:    68     num_inner:     0     f: -3.955734e-09   |grad|: 9.412517e-04   exceeded trust region
# REJ TR-   k:    69     num_inner:     0     f: -3.955734e-09   |grad|: 9.412517e-04   exceeded trust region
# REJ TR-   k:    70     num_inner:     0     f: -3.955734e-09   |grad|: 9.412517e-04   exceeded trust region
# REJ TR-   k:    71     num_inner:     0     f: -3.955734e-09   |grad|: 9.412517e-04   exceeded trust region
#  +++ Detected many consecutive TR- (radius decreases).
#  +++ Consider decreasing options.Delta_bar by an order of magnitude.
#  +++ Current values: Delta_bar = 19.6192 and Delta0 = 2.4524
# REJ TR-   k:    72     num_inner:     0     f: -3.955734e-09   |grad|: 9.412517e-04   exceeded trust region
# REJ TR-   k:    73     num_inner:     0     f: -3.955734e-09   |grad|: 9.412517e-04   exceeded trust region
# REJ TR-   k:    74     num_inner:     0     f: -3.955734e-09   |grad|: 9.412517e-04   exceeded trust region
# REJ TR-   k:    75     num_inner:     0     f: -3.955734e-09   |grad|: 9.412517e-04   exceeded trust region
# REJ TR-   k:    76     num_inner:     0     f: -3.955734e-09   |grad|: 9.412517e-04   exceeded trust region
# acc TR+   k:    77     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:    78     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:    79     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:    80     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:    81     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
#  +++ Detected many consecutive TR- (radius decreases).
#  +++ Consider decreasing options.Delta_bar by an order of magnitude.
#  +++ Current values: Delta_bar = 19.6192 and Delta0 = 2.4524
# REJ TR-   k:    82     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:    83     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:    84     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:    85     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:    86     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:    87     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:    88     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:    89     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:    90     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:    91     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:    92     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:    93     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:    94     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:    95     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:    96     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:    97     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:    98     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:    99     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   100     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   101     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   102     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   103     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   104     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   105     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   106     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   107     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   108     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   109     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   110     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   111     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   112     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   113     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   114     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   115     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   116     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   117     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   118     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   119     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   120     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   121     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   122     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   123     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   124     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   125     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   126     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   127     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   128     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   129     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   130     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   131     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   132     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   133     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   134     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   135     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   136     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   137     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   138     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   139     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   140     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   141     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   142     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   143     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   144     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   145     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   146     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   147     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   148     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   149     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   150     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   151     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   152     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   153     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   154     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   155     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   156     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   157     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   158     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   159     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   160     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   161     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   162     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   163     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   164     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   165     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   166     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   167     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   168     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   169     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   170     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   171     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   172     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   173     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   174     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   175     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   176     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   177     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   178     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   179     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   180     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   181     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   182     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   183     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   184     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   185     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   186     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   187     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   188     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   189     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   190     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   191     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   192     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   193     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   194     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   195     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   196     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   197     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   198     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   199     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   200     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   201     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   202     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   203     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   204     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   205     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   206     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   207     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   208     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   209     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   210     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   211     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   212     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   213     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   214     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   215     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   216     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   217     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   218     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   219     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   220     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   221     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   222     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   223     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   224     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   225     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   226     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   227     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   228     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   229     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   230     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   231     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   232     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   233     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   234     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   235     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   236     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   237     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   238     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   239     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   240     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   241     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   242     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   243     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   244     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   245     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   246     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   247     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   248     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   249     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   250     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   251     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   252     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   253     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   254     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   255     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   256     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   257     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   258     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   259     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   260     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   261     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   262     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   263     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   264     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   265     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   266     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   267     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   268     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   269     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   270     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   271     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   272     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   273     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   274     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   275     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   276     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   277     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   278     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   279     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   280     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   281     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   282     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   283     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   284     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   285     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   286     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   287     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   288     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   289     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   290     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   291     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   292     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   293     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   294     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   295     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   296     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   297     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   298     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   299     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   300     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   301     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   302     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   303     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   304     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   305     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   306     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   307     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   308     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   309     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   310     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   311     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   312     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   313     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   314     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   315     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   316     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   317     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   318     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   319     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   320     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   321     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   322     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   323     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   324     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   325     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   326     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   327     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   328     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   329     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   330     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   331     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   332     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   333     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   334     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   335     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   336     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   337     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   338     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   339     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   340     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   341     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   342     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   343     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   344     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   345     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   346     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   347     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   348     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   349     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   350     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   351     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   352     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   353     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   354     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   355     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   356     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   357     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   358     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   359     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   360     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   361     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   362     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   363     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   364     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   365     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   366     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   367     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   368     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   369     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   370     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   371     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   372     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   373     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   374     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   375     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   376     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   377     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   378     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   379     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   380     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   381     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   382     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   383     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   384     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   385     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   386     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   387     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   388     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   389     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   390     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   391     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   392     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   393     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   394     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   395     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   396     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   397     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   398     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   399     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   400     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   401     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   402     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   403     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   404     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   405     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   406     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   407     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   408     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   409     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   410     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   411     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   412     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   413     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   414     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   415     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   416     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   417     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   418     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   419     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   420     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   421     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   422     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   423     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   424     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   425     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   426     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   427     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   428     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# REJ TR-   k:   429     num_inner:     0     f: -4.407980e-09   |grad|: 9.412516e-04   exceeded trust region
# ...
# REJ TR-   k:  2854     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2855     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2856     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2857     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2858     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2859     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2860     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2861     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2862     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2863     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2864     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2865     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2866     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2867     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2868     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2869     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2870     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2871     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2872     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2873     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2874     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2875     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2876     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2877     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2878     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2879     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2880     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2881     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2882     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2883     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2884     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2885     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2886     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2887     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2888     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2889     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2890     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2891     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2892     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2893     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2894     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2895     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2896     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2897     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2898     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2899     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2900     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2901     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2902     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2903     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2904     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2905     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2906     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2907     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2908     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2909     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2910     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2911     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2912     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2913     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2914     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2915     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2916     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2917     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2918     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2919     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2920     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2921     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2922     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2923     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2924     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2925     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2926     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2927     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2928     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2929     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2930     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2931     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2932     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2933     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2934     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2935     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2936     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2937     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2938     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2939     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2940     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2941     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2942     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2943     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2944     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2945     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2946     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2947     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2948     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2949     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2950     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2951     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2952     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2953     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2954     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2955     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2956     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2957     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2958     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2959     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2960     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2961     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2962     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2963     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2964     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2965     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2966     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2967     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2968     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2969     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2970     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2971     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2972     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2973     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2974     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2975     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2976     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2977     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2978     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2979     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2980     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2981     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2982     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2983     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2984     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2985     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2986     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2987     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2988     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2989     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2990     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2991     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2992     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2993     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2994     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2995     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2996     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2997     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# REJ TR-   k:  2998     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  2999     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# acc TR+   k:  3000     num_inner:     0     f: +1.834462e-08   |grad|: 2.496753e-02   exceeded trust region
# Terminated - max iterations reached after 0.35 seconds.

# %%
Y_star = Y_D3
#X = direction_to_position(np.concatenate([Y_star[0][:3,:],U[:3,:3]@np.diag(S)[:3,:]@V],axis=1),C,D)
if len(Y_star) == 2:
    X = direction_to_position(np.concatenate([Y_star[0],Y_star[1]],axis=1),C,D)
else:
    X = direction_to_position(Y_star,C,D)


R = rotation_matrix_from_vectors(X[1,:], norm(e2))
R_ = rotation_matrix_from_vectors(R@X[0,:], norm(e1))
Rz_flip = np.diag((1,1,1))

print(X@R.transpose()@Rz_flip)
print(np.linalg.norm(X[-1,:]@R.transpose()@R_.transpose()@Rz_flip-position))
print(np.linalg.norm((X[-1,:]-X[-2,:])@R.transpose()@R_.transpose()@Rz_flip/scale_shift-direction))
X = X@R.transpose()@Rz_flip
# Out:
# (3, 39) (14, 39) (39, 39)
# [[ 7.99999999e+02  1.01663490e-06  1.24685742e-06]
#  [ 7.17970894e-23  8.00000005e+02 -4.85734308e-14]
#  [ 8.10733959e-06  2.22551342e-05  8.00000012e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 2.39571431e-02 -2.49999895e+01  1.09627762e-05]
#  [-7.99975746e+02 -2.57644052e+01  1.93830510e-05]
#  [ 5.54548834e-01 -5.80500983e+02  7.08407920e+01]
#  [-7.99444657e+02 -5.81366148e+02  7.00462284e+01]
#  [ 8.20425311e-01 -5.64096866e+02 -2.14782794e+02]
#  [ 1.60120080e-04 -5.40000047e+02  5.84853792e+02]
#  [ 1.58838689e-04 -5.40000048e+02  5.84853793e+02]
#  [-7.99999419e+02 -5.40000020e+02  5.84033155e+02]
#  [-1.07208131e-05  1.69999988e+02  5.84999990e+02]
#  [ 9.35100259e-07 -6.29999977e+02  5.85000025e+02]]
# 3.420752409242295e-05
# 6.371575038278272e-08

# %%
def direction_to_position(Y,C,D):
    print(Y.shape, C.shape, D.shape)
    X = np.linalg.pinv(C@C.transpose())@C@D@Y.transpose()
    X = X - X[3,:]
    
    #if X[0,0]<0:
      #  X = -X
    
    v = X[0,:]
    R = rotation_matrix_from_vectors(v/np.linalg.norm(v),e1/np.linalg.norm(e1))
    
    return X@R.transpose()

# %%
print(np.arccos(Y_D3[1].transpose()[19-n_anchor,:]@norm(e2))*180/np.pi)
print(Y_D3[1].transpose()[19-n_anchor,:], norm(e2))
print(Rz(np.arccos(Y_star[1].transpose()[19-n_anchor,:]@norm(e2)))[:3,:3]@norm(e2)-Y_star[1].transpose()[19-n_anchor,:])
# Out:
# 0.912029275610479
# [1.59172395e-02 9.99873313e-01 7.95120020e-06] [0. 1. 0.]
# [1.31273291e-12 0.00000000e+00 1.00159986e-07]

# %%
def rotation_matrix_from_vectors(vec1, vec2):
    """ Find the rotation matrix that aligns vec1 to vec2
    :param vec1: A 3d "source" vector
    :param vec2: A 3d "destination" vector
    :return mat: A transform matrix (3x3) which when applied to vec1, aligns it with vec2.
    """
    a, b = (vec1 / np.linalg.norm(vec1)).reshape(3), (vec2 / np.linalg.norm(vec2)).reshape(3)
    v = np.cross(a, b)
    c = np.dot(a, b)
    s = np.linalg.norm(v)
    kmat = np.array([[0, -v[2], v[1]], [v[2], 0, -v[0]], [-v[1], v[0], 0]])
    rotation_matrix = np.eye(3) + kmat + kmat.dot(kmat) * ((1 - c) / (s ** 2))
    return rotation_matrix

# %%
joint = sol_to_config_kuka_KR_10_R1100(G,Y_D3,new_edge_order,n_anchor,scale_shift)
joint.append(0)
#joint[1] = -joint[1]
#joint[-2] = np.pi-joint[-2]
print([180/np.pi*j for j in joint])
print(pose_robot_(joint,'camera'))
print(position,direction)
print(np.linalg.norm(pose_robot_(joint,'camera')[:3,3] - position), np.linalg.norm(direction - pose_robot_(joint,'camera')[:3,0]))
